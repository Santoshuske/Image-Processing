# %% [markdown]
# <a href="https://colab.research.google.com/github/Santoshuske/Image-Processing/blob/main/IMG_PRP_TIG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing libraries
import tensorflow
import keras
import os
import glob
from skimage import io
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Animals/Animals/Tiger'

# %%
os.chdir('drive/My Drive/Colab Notebooks/Animals/Animals/Tiger')
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-38772f2bbd8c> in <module>()
# ----> 1 os.chdir('drive/My Drive/Colab Notebooks/Animals/Animals/Tiger')
#       2 os.getcwd()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/Animals/Animals/Tiger'

# %%
os.listdir()
# Out:
# ['pexels-photo-247615.jpeg',
#  'pexels-photo-951007.jpeg',
#  'pexels-photo-3777200.jpeg',
#  'pexels-photo-145973.jpeg',
#  'pexels-photo-3275319.jpeg',
#  'pexels-photo-145979.jpeg',
#  'sumatran-tiger-tiger-big-cat-stripes-46251.jpeg',
#  'pexels-photo-3860030.jpeg',
#  'pexels-photo-145932.jpeg',
#  'pexels-photo-2055100.jpeg',
#  'panthera-tigris-altaica-tiger-siberian-amurtiger-162173.jpeg',
#  'panthera-tigris-altaica-tiger-siberian-amurtiger-162203.jpeg',
#  'pexels-photo-236599.jpeg',
#  'pexels-photo-145939.jpeg',
#  'pexels-photo-982240.jpeg',
#  'tiger-cub-tiger-cub-big-cat-64152.jpeg',
#  'pexels-photo-302276.jpeg',
#  'pexels-photo-302304.jpeg',
#  'tiger-predator-animal-tooth-47312.jpeg',
#  'pexels-photo-2668605.jpeg',
#  'pexels-photo-145900.jpeg',
#  'pexels-photo-774544.jpeg',
#  'pexels-photo-145899 (1).jpeg',
#  'pexels-photo-2649841.jpeg',
#  'pexels-photo-145971.jpeg',
#  'pexels-photo-572861.jpeg',
#  'pexels-photo-2689436.jpeg',
# ...

# %%
#acessing an image file from datset classes
animal_path='/content/drive/My Drive/Colab Notebooks/Animals/Animals/Tiger'
image=io.imread(os.listdir()[4])
#ploting original image
i, (im1)=plt.subplots(1)
i.set_figwidth(15)
im1.imshow(image)

# %%
#ploting original image and RGB channels
i,(im1,im2,im3,im4)=plt.subplots(1,4,sharey=True)
i.set_figwidth(20)

im1.imshow(image)  #original image
im2.imshow(image[:,:,0])  #RED
im3.imshow(image[:,:,1])  #GREEN
im4.imshow(image[:,:,2])  #BLUE
i.suptitle('original and RGB image channels')
# Out:
# Text(0.5, 0.98, 'original and RGB image channels')

# %%
#!pip instal sckitt image
import skimage
from skimage.io import imread
from skimage.transform import resize

gray_image=skimage.color.rgb2gray(image)
plt.imshow(gray_image,cmap='gray')

# %%
norm_image=(gray_image-np.min(gray_image))/np.max(gray_image)-np.min(gray_image)
plt.imshow(norm_image)

# %%
#import libraries
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

#convert to numpy array
data=img_to_array(image)

#expand dimension to one sample
samples=expand_dims(image,0)

#creat image to data argumentation generator
datagen=ImageDataGenerator(width_shift_range=[-200,200])

#creat an iterator
it=datagen.flow(samples,batch_size=1)
fig,im=plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(it)[0].astype('uint8')
 
    # plot image
    im[i].imshow(image)

# %%
# ImageDataGenerator for flipping
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip=True)

# %%
# create an iterator
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=3, ncols=1, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(it)[0].astype('uint8')
 
    # plot image
    im[i].imshow(image)

# %%
datagen = ImageDataGenerator(rotation_range=30, fill_mode='nearest')
# create an iterator
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(it)[0].astype('uint8')
 
    # plot image
    im[i].imshow(image)

# %%
# creating the image data generator to standardize images
datagen = ImageDataGenerator(featurewise_center =True,
      featurewise_std_normalization = True)
# create an iterator
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=1, ncols=3, figsize=(20,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(it)[0].astype('uint8')
 
    # plot image
    im[i].imshow(image)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
