# %% [markdown]
# <a href="https://colab.research.google.com/github/Santoshuske/Image-Processing/blob/main/image_preprocessLoin1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing libraries
import tensorflow 
import keras  
import os
import glob 
from skimage import io 
import random 
import numpy as np
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('drive/My Drive/Colab Notebooks/Animals/Animals/Lion')
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Animals/Animals/Lion'

# %%
os.listdir()
# Out:
# ['lion-wild-africa-african.jpg',
#  'pexels-photo-1622508.jpeg',
#  'africa-animal-big-brown-41176.jpeg',
#  'pexels-photo-2220336.jpeg',
#  'pexels-photo-5078931.jpeg',
#  'pexels-photo-4913603.jpeg',
#  'pexels-photo-4032590.jpeg',
#  'pexels-photo-3284268.jpeg',
#  'lion-predator-big-cat-safari-46522.jpeg',
#  'pexels-photo-730539.jpeg',
#  'pexels-photo-1187987.jpeg',
#  'pexels-photo-209077.jpeg',
#  'africa-animal-big-carnivore-41178.jpeg',
#  'pexels-photo-3284299.jpeg',
#  'pexels-photo-4913601.jpeg',
#  'pexels-photo-321096.jpeg',
#  'pexels-photo-3498323.jpeg',
#  'pexels-photo-2741798.jpeg',
#  'pexels-photo-1300960.jpeg',
#  'pexels-photo-1598377.jpeg',
#  'pexels-photo-2674052.jpeg',
#  'pexels-photo-3284291.jpeg',
#  'africa-african-animal-cat-41315.jpeg',
#  'pexels-photo-3651335.jpeg',
#  'pexels-photo-4913587.jpeg',
#  'pexels-photo-4045962.jpeg',
#  'pexels-photo-4741843.jpeg',
#  'pexels-photo-1362012.jpeg',
#  'pexels-photo-730534.jpeg',
#  'pexels-photo-4595865.jpeg',
#  'pexels-photo-68421.jpeg',
#  'pexels-photo-4168329.jpeg']

# %%
# accessing an image file from the dataset classes
animal_path = '/content/drive/My Drive/Colab Notebooks/Animals/Animals/Lion'
image = io.imread(os.listdir()[4])  

# plotting the original image
i, (im1) = plt.subplots(1)
i.set_figwidth(15)
im1.imshow(image)

# %%
# plotting the original image and the RGB channels  

i, (im1, im2, im3, im4) = plt.subplots(1, 4, sharey=True)
i.set_figwidth(20) 

im1.imshow(image)  #Original image
im2.imshow(image[:, : , 0]) #Red
im3.imshow(image[:, : , 1]) #Green
im4.imshow(image[:, : , 2]) #Blue
i.suptitle('Original & RGB image channels')
# Out:
# Text(0.5, 0.98, 'Original & RGB image channels')

# %%
##!pip install scikit-image
import skimage
from skimage.io import imread
from skimage.transform import resize

gray_image = skimage.color.rgb2gray(image)
plt.imshow(gray_image, cmap = 'gray')

# %%
norm_image = (gray_image - np.min(gray_image)) / (np.max(gray_image) - np.min(gray_image))
plt.imshow(norm_image)

# %%
# import libraries

from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

# convert to numpy array
data = img_to_array(image)

# expand dimension to one sample
samples = expand_dims(image, 0)

# create image data augmentation generator
datagen = ImageDataGenerator(width_shift_range=[-200,200])

# create an iterator
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(it)[0].astype('uint8')
 
    # plot image
    im[i].imshow(image)

# %%
# ImageDataGenerator for flipping
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip=True)

# %%
# create an iterator
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=3, ncols=1, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(it)[0].astype('uint8')
 
    # plot image
    im[i].imshow(image)

# %%
datagen = ImageDataGenerator(rotation_range=30, fill_mode='nearest')
# create an iterator
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(it)[0].astype('uint8')
 
    # plot image
    im[i].imshow(image)

# %%
# creating the image data generator to standardize images
datagen = ImageDataGenerator(featurewise_center =True,
      featurewise_std_normalization = True)
# create an iterator
it = datagen.flow(samples, batch_size=1)
fig, im = plt.subplots(nrows=1, ncols=3, figsize=(15,15))

# generate batch of images
for i in range(3):

    # convert to unsigned integers
    image = next(it)[0].astype('uint8')
 
    # plot image
    im[i].imshow(image)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
